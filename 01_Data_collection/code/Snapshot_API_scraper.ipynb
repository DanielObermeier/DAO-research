# %% [markdown]
# # DAO - Snapshot votings
#
# This script downloads all spaces, proposals, votes from the snapshot API (https://docs.snapshot.org/graphql-api) and stores the data in a local SQLite data base.
#
#
#
# Notes:
# - To speed up the process (and get as close as possible to the API limit), I use multithreading whenever possible. However, as the API gets more popular, the rate limit has decreased causing 429 errors. Turning off multithreading mitigates this problem.

# %% [markdown]
# ## Table of content
#
# 1. Import libraries
# 2. Define function to get spaces
# 3. Define function to get proposal information
# 4. Define function to get votes information
# 5. Define function to get follower information
# 6. Define function to get user information
# 7. Create a sqlite database
# 8. Call all functions and store the results in the sqlite database
# 9. Show descriptives of available DAO data

# %% [markdown]
# ## 1. Import libraries

# %%
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Get spaces
# The following function allows to to retrieve a predefined number of spaces from the Snapshot API and returns a list of dictionaries.
# If you want to query all spaces, then set space_limit to 10,000. Currently there are ~9,000 spaces. Unfortunately, there is not way to determine the number of spaces in advance.
#
# It is also important to note that only 20 spaces can be retrieved at once.

# %%
def get_spaces(space_limit):
    """
    this function queries the snapshot graphql API and retrieves all spaces together with some meta data
    pram space_limit: integer that indicates up to which limit the skip counter runs
    return: list of unique spaces on snapshot
    """

    # import libraries
    import requests
    import json
    import time

    # initiate skip counter
    skip = 0 

    # initiate list to store all spaces
    result_list = []


    #define a API request function 

    def API_call(url, query):
        # send query to API
        r = requests.post(url, json={'query': query})

        # initiate list to be filled later on
        dict_list = []

        # check if status code is valid
        if r.status_code == 200:
            
            # load query result as json
            r_dict = json.loads(r.text)

            # progress notification
            print("status_code: " + str(r.status_code))

            # access space data from API response
            space_list = r_dict["data"]["spaces"]

            # loop through all spaces 
            for space in space_list:
                    
                space_dict = {}
                space_dict["space_id"] = space["id"]
                space_dict["space_name"] = space["name"]
                space_dict["about"] = space["about"]
                space_dict["network"] = space["network"]
                space_dict["symbol"] = space["symbol"]
                space_dict["number_of_strategies"] = len(space["strategies"])
                space_dict["strategies_list"] = space["strategies"]
                space_dict["number_of_admins"] = len(space["admins"])
                space_dict["admins"] = space["admins"]
                space_dict["number_of_members"] = len(space["members"])
                space_dict["members_list"] = space["members"]
                space_dict["filters_minScore"] = space["filters"]["minScore"]
                space_dict["filters_onlyMembers"] = space["filters"]["onlyMembers"]
                space_dict["plugins"] = space["plugins"]
                dict_list.append(space_dict)
            return dict_list
                
        else:
            # error message
            print("Invalide status code: "+ str(r.status_code))
            return r.status_code



    # snapshot does not tell how many spaces there are. Skipping restarts the loop after all spaces have been queried. Solution is to filter duplicates at the end.
    while skip < space_limit: 
        # progress notification
        print("skip: "+str(skip))


        # define graphQL query string
        query = """{
                    spaces(
                        first: 20,
                        skip: """+str(skip)+""",
                        orderBy: "created",
                        orderDirection: asc
                    ) {
                        id
                        name
                        about
                        network
                        symbol
                        strategies {
                        name
                        params
                        }
                        admins
                        members
                        filters {
                        minScore
                        onlyMembers
                        }
                        plugins
                    }
                    } """

        url = 'https://hub.snapshot.org/graphql'

        # call the API
        result = API_call(url, query)
        
        if type(result) == list:
            # add list of new spaces to final list
            result_list = result_list+result
        else:
            
            if result == 429:
                print("Error code 429: waiting 10s before retry")
                time.sleep(10)

                result2 = API_call(url, query)
                if type(result2) == list:
                    # add list of new spaces to final list
                    result_list = result_list+result2
                else:
                    print("retry has failed")
                    break
            else: 
                print("Stopped due to error code: "+ str(result))
                break

        # incriment skip by 20 (API does not allow to skip more spaces at every iteration)
        skip += 20


    # filter duplicates
    seen = list()
    uniq_spaces = [x for x in result_list if x not in seen and not seen.append(x)]    
    
    # return final list of unique spaces
    return uniq_spaces

# %% [markdown]
# #### Call the function to get all spaces

# %%
# call the function and store the output as a csv file (as a backup)
spaces = get_spaces(12000)

df_spaces = pd.DataFrame(spaces)

# save data as csv
df_spaces.to_csv('snapshot_spaces_nov2022.csv', index=False, sep=";")

# read csv data backup 
#df_spaces = pd.read_csv('snapshot_spaces.csv',  sep=";")
# Out:
# skip: 0
# status_code: 200
# skip: 20
# status_code: 200
# skip: 40
# status_code: 200
# skip: 60
# status_code: 200
# skip: 80
# status_code: 200
# skip: 100
# status_code: 200
# skip: 120
# status_code: 200
# skip: 140
# status_code: 200
# skip: 160
# status_code: 200
# skip: 180
# status_code: 200
# skip: 200
# status_code: 200
# skip: 220
# status_code: 200
# skip: 240
# status_code: 200
# skip: 260
# status_code: 200
# skip: 280
# status_code: 200
# skip: 300
# status_code: 200
# skip: 320
# status_code: 200
# skip: 340
# status_code: 200
# skip: 360
# status_code: 200
# skip: 380
# status_code: 200
# skip: 400
# status_code: 200
# skip: 420
# status_code: 200
# skip: 440
# status_code: 200
# skip: 460
# status_code: 200
# skip: 480
# status_code: 200
# skip: 500
# status_code: 200
# skip: 520
# status_code: 200
# skip: 540
# status_code: 200
# skip: 560
# status_code: 200
# skip: 580
# status_code: 200
# skip: 600
# status_code: 200
# skip: 620
# status_code: 200
# skip: 640
# status_code: 200
# skip: 660
# status_code: 200
# skip: 680
# status_code: 200
# skip: 700
# status_code: 200
# skip: 720
# status_code: 200
# skip: 740
# status_code: 200
# skip: 760
# status_code: 200
# skip: 780
# status_code: 200
# skip: 800
# status_code: 200
# skip: 820
# status_code: 200
# skip: 840
# status_code: 200
# skip: 860
# status_code: 200
# skip: 880
# status_code: 200
# skip: 900
# status_code: 200
# skip: 920
# status_code: 200
# skip: 940
# status_code: 200
# skip: 960
# status_code: 200
# skip: 980
# status_code: 200
# skip: 1000
# status_code: 200
# skip: 1020
# status_code: 200
# skip: 1040
# status_code: 200
# skip: 1060
# status_code: 200
# skip: 1080
# status_code: 200
# skip: 1100
# status_code: 200
# skip: 1120
# status_code: 200
# skip: 1140
# status_code: 200
# skip: 1160
# status_code: 200
# skip: 1180
# status_code: 200
# skip: 1200
# status_code: 200
# skip: 1220
# status_code: 200
# skip: 1240
# status_code: 200
# skip: 1260
# status_code: 200
# skip: 1280
# status_code: 200
# skip: 1300
# status_code: 200
# skip: 1320
# status_code: 200
# skip: 1340
# status_code: 200
# skip: 1360
# status_code: 200
# skip: 1380
# status_code: 200
# skip: 1400
# status_code: 200
# skip: 1420
# status_code: 200
# skip: 1440
# skip: 10940
# status_code: 200
# skip: 10960
# status_code: 200
# skip: 10980
# status_code: 200
# skip: 11000
# status_code: 200
# skip: 11020
# status_code: 200
# skip: 11040
# status_code: 200
# skip: 11060
# status_code: 200
# skip: 11080
# status_code: 200
# skip: 11100
# status_code: 200
# skip: 11120
# status_code: 200
# skip: 11140
# status_code: 200
# skip: 11160
# status_code: 200
# skip: 11180
# status_code: 200
# skip: 11200
# status_code: 200
# skip: 11220
# status_code: 200
# skip: 11240
# status_code: 200
# skip: 11260
# status_code: 200
# skip: 11280
# status_code: 200
# skip: 11300
# status_code: 200
# skip: 11320
# status_code: 200
# skip: 11340
# status_code: 200
# skip: 11360
# status_code: 200
# skip: 11380
# status_code: 200
# skip: 11400
# status_code: 200
# skip: 11420
# status_code: 200
# skip: 11440
# status_code: 200
# skip: 11460
# status_code: 200
# skip: 11480
# status_code: 200
# skip: 11500
# status_code: 200
# skip: 11520
# status_code: 200
# skip: 11540
# status_code: 200
# skip: 11560
# status_code: 200
# skip: 11580
# status_code: 200
# skip: 11600
# status_code: 200
# skip: 11620
# status_code: 200
# skip: 11640
# status_code: 200
# skip: 11660
# status_code: 200
# skip: 11680
# status_code: 200
# skip: 11700
# status_code: 200
# skip: 11720
# status_code: 200
# skip: 11740
# status_code: 200
# skip: 11760
# status_code: 200
# skip: 11780
# status_code: 200
# skip: 11800
# status_code: 200
# skip: 11820
# status_code: 200
# skip: 11840
# status_code: 200
# skip: 11860
# status_code: 200
# skip: 11880
# status_code: 200
# skip: 11900
# status_code: 200
# skip: 11920
# status_code: 200
# skip: 11940
# status_code: 200
# skip: 11960
# status_code: 200
# skip: 11980
# status_code: 200

# %% [markdown]
# ## 3. Get all proposals for every space
# The following function allows to retrieve all proposals for a space and returns a list of dictionaries.

# %%
# define a function that retrieves all proposals of a space

def get_proposals(space_id):
  """
    this function queries the snapshot graphql API and retrieves all proposals together with some meta data for a given space
    pram space_id: id of a space (can be retrieved by calling the space endpoint)
    return: list of all proposals for a given space
  """

  # import libraries
  import requests
  import json
  import time

  # init list to store all proposal dicts
  proposal_list = []

  # define query string
  query = """{
    proposals (
      first: 10000,
      skip: 0,
      where: {
        space_in: ["%s"],
        state: "all"
      },
      orderBy: "created",
      orderDirection: desc
    ) {
      id
      title
      body
      choices
      start
      end
      snapshot
      state
      scores
      scores_by_strategy
      scores_total
      scores_updated
      author
      space {
        id
        name
      }
    }
  } """ % (space_id)

  # progress notification
  print("query proposal for: " + space_id)

  # API query routine
  url = 'https://hub.snapshot.org/graphql'
  r = requests.post(url, json={'query': query})
  if r.status_code == 200:
    r_dict = json.loads(r.text)

    # loop through list of returned proposals and add space variables
    for proposal in r_dict["data"]["proposals"]:

        proposal_dict = {}
        
        # extract space id and name from the space entry of the original dict
        proposal_dict["space_id"] =  proposal["space"]["id"]
        proposal_dict["space_name"] = proposal["space"]["name"]

        # add space id and name dict to the original dict
        proposal_dict = {**proposal_dict, **proposal}

        # delete space from original dict
        del proposal_dict['space']
        proposal_list.append(proposal_dict)
  else:
    print("Error! status code: "+str(r.status_code))
    if r.status_code == 429:
      print("retry after waiting 3s")
      time.sleep(3)
    get_proposals(space_id)

  # return final list of proposal dicts
  return proposal_list

# %%
# creat multithread function for proposal API call

def multithread_get_proposals(space_list):
    """
    this function splits up the task to loop through a list of space IDs and retrievs a list of proposals for all spaces.
    :param: space_list: list of space IDs
    return: list of all proposals (for all spaces)
    """

    # import libraries
    import requests
    from concurrent.futures import ThreadPoolExecutor, as_completed



    # initiate proposal list to be filled 
    nested_proposal_dict_list = []
    proposal_dict_list = []

    # define a runner that splits up the list of spaces among a number of workers 
    def runner():
        threads= []
        with ThreadPoolExecutor(max_workers=9) as executor: #more than 10 workers results in significant more 429 errors
            for space_id in space_list:
                threads.append(executor.submit(get_proposals, space_id))

            for task in as_completed(threads):
                nested_proposal_dict_list.append(task.result())    
    # call the runner  
    runner()

    # unpack the lists of proposals for every space into one list of proposals for all spaces
    for dict_list in nested_proposal_dict_list:
        for proposal_dict in dict_list:
            proposal_dict_list.append(proposal_dict)

    # return list of all proposal dicts
    return proposal_dict_list

# %% [markdown]
# #### Get all proposals (multithread)

# %%
# get list of all space ids
space_list = df_spaces["space_id"]

# shorter list for tests
# space_list = list(df_spaces["space_id"][0:100])

# query all spaces 
prop_list = multithread_get_proposals(space_list)

# save the resulting list of dicts as csv file for backup 
#df_proposals = pd.DataFrame(prop_list)
#df_proposals.to_csv('snapshot_proposals_nov2022.csv', index=False, sep=";")

# read file from backup 
#df_proposals = pd.read_csv('snapshot_proposals_nov2022.csv',  sep=";")
# Out:
# query proposal for: bonustrack.eth
# query proposal for: fabien.eth
# query proposal for: ichi.eth
# query proposal for: loyalfinance.eth
# query proposal for: damflux.eth
# query proposal for: ufode.eth
# query proposal for: boringvote.eth
# query proposal for: relayernetwork.eth
# query proposal for: prophetfinance.eth
# query proposal for: liddao.eth
# query proposal for: idlefinance.ethquery proposal for: scradclub.eth
#
# query proposal for: pub-finance.eth
# query proposal for: saffronfinance.eth
# query proposal for: sovi.eth
# query proposal for: monportefeuille.eth
# query proposal for: flowcommunity.eth
# query proposal for: tradersquare.eth
# query proposal for: xionetwork.eth
# query proposal for: minkfinance.eth
# query proposal for: mutualdao.eth
# query proposal for: esd.eth
# query proposal for: vote.southchain.eth
# query proposal for: flushlol.eth
# query proposal for: xethfinance.eth
# query proposal for: dodobird.eth
# query proposal for: archerdao.eth
# query proposal for: bbra.eth
# query proposal for: truegov.eth
# query proposal for: keep2r.eth
# query proposal for: meter-eth.eth
# query proposal for: meter-mainnet.eth
# query proposal for: communitytoken.eth
# query proposal for: ceproject.eth
# query proposal for: dfking.eth
# query proposal for: swarmnetwork.eth
# query proposal for: gokai.eth
# query proposal for: midas-defi.eth
# query proposal for: btfinance.eth
# query proposal for: 0xEaDC218Ac4cB7895a5A56e6484646b48f841C45a.eth
# query proposal for: moltenfinance.eth
# query proposal for: decentralgames.eth
# query proposal for: metapoolgov.eth
# query proposal for: nftgoddessart.eth
# query proposal for: coopnetwork.eth
# query proposal for: badgerdao.eth
# query proposal for: yam.eth
# query proposal for: gov.cap.eth
# query proposal for: honeyfinance.eth
# query proposal for: aavegotchi.eth
# query proposal for: firestack.eth
# query proposal for: wse.eth
# query proposal for: baovotes.eth
# query proposal for: yfdfi.eth
# query proposal for: unitprotocol.eth
# query proposal for: thescientificblock.eth
# query proposal for: unidexapp.eth
# query proposal for: ubxt.eth
# query proposal for: hollaex.eth
# query proposal for: noderunners.eth
# query proposal for: xdaistake.eth
# query proposal for: compgov.eth
# query proposal for: earndeficoin.eth
# query proposal for: multiplierfinance.eth
# query proposal for: wearedesign.eth
# query proposal for: tranche.eth
# query proposal for: trinityprotocol.eth
# query proposal for: yfi3money.eth
# query proposal for: keeperfi.eth
# query proposal for: uniqueone.eth
# query proposal for: trism.eth
# query proposal for: changbinhe.ethquery proposal for: supersam.eth
#
# query proposal for: yup.eth
# query proposal for: snapshot.puul.eth
# query proposal for: keyfi-app.eth
# query proposal for: basiscash.ethquery proposal for: bombtoken.eth
#
# query proposal for: vote.defi3dot0.eth
# query proposal for: rbase.eth
# query proposal for: tacoswap.eth
# query proposal for: wrappedhbar.eth
# query proposal for: defidolla.eth
# query proposal for: dappdigest.eth
# query proposal for: adeptcamp.eth
# query proposal for: CryptoKaiju.eth
# query proposal for: basisdollar.eth
# query proposal for: 2based.eth
# query proposal for: lrctoken.eth
# Error! status code: 429
# retry after waiting 3sError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wrappedhbar.ethquery proposal for: defidolla.eth
#
# query proposal for: adeptcamp.eth
# query proposal for: tacoswap.eth
# query proposal for: dappdigest.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: 2based.ethquery proposal for: CryptoKaiju.ethquery proposal for: lrctoken.eth
#
#
# query proposal for: basisdollar.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wrappedhbar.eth
# query proposal for: defidolla.eth
# query proposal for: adeptcamp.ethquery proposal for: tacoswap.eth
#
# query proposal for: dappdigest.eth
# query proposal for: CryptoKaiju.eth
# query proposal for: basisdollar.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: lrctoken.eth
# query proposal for: 2based.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: adeptcamp.ethquery proposal for: tacoswap.ethquery proposal for: defidolla.eth
#
#
# query proposal for: wrappedhbar.ethquery proposal for: dappdigest.eth
#
# query proposal for: CryptoKaiju.eth
# query proposal for: basisdollar.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: 2based.ethquery proposal for: lrctoken.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# Error! status code: 429
# retry after waiting 3sretry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: adeptcamp.ethquery proposal for: tacoswap.eth
#
# query proposal for: wrappedhbar.eth
# query proposal for: defidolla.ethquery proposal for: CryptoKaiju.eth
#
# query proposal for: basisdollar.eth
# query proposal for: lrctoken.ethquery proposal for: 2based.ethquery proposal for: dappdigest.eth
#
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: adeptcamp.eth
# query proposal for: CryptoKaiju.eth
# query proposal for: tacoswap.eth
# query proposal for: defidolla.eth
# query proposal for: wrappedhbar.eth
# query proposal for: basisdollar.eth
# query proposal for: defisafedao.eth
# query proposal for: lrctoken.eth
# query proposal for: 2based.eth
# query proposal for: dappdigest.eth
# query proposal for: gainswap.eth
# query proposal for: spider-dao.eth
# query proposal for: amp.eth
# query proposal for: truefigov.eth
# query proposal for: test.truefigov.eth
# query proposal for: dxd.eth
# query proposal for: frax.eth
# query proposal for: streamix.eth
# query proposal for: dgovn.eth
# query proposal for: finnexus.eth
# query proposal for: cryptokek.eth
# query proposal for: carrotswap.eth
# query proposal for: rifttoken.eth
# query proposal for: socks-gov.eth
# query proposal for: hypnotube.eth
# query proposal for: unfederalreserve.eth
# query proposal for: latif.eth
# query proposal for: daostack-alchemy.eth
# query proposal for: vote.theborg.eth
# query proposal for: bdollar.eth
# query proposal for: nftx.eth
# query proposal for: devcondemo.eth
# query proposal for: ndxfi.eth
# query proposal for: votesfinance.eth
# query proposal for: cryptobond.eth
# query proposal for: ndx.eth
# query proposal for: gdao.eth
# query proposal for: bscex.eth
# query proposal for: aria.eth
# query proposal for: pollendefi.eth
# query proposal for: kian.eth
# query proposal for: zaifinance.eth
# query proposal for: 1sd.eth
# query proposal for: primitive.eth
# query proposal for: friendswithbenefits.eth
# query proposal for: mithcash.eth
# query proposal for: dsd.eth
# query proposal for: carvefinance.eth
# query proposal for: batdollar.eth
# query proposal for: mind.eth
# query proposal for: bitcoinsov.eth
# query proposal for: friskdao.eth
# query proposal for: supernovacash.eth
# query proposal for: vote-perp.eth
# query proposal for: dittomoney.eth
# query proposal for: ironbankfi.eth
# query proposal for: coffeeswap.eth
# query proposal for: beastdao.eth
# query proposal for: spicedao.eth
# query proposal for: emptysetgold.eth
# query proposal for: yftether.eth
# query proposal for: barnbridge.eth
# query proposal for: derivadao.eth
# query proposal for: lunacore.eth
# query proposal for: emptysetbitcoin.eth
# query proposal for: recovertoken.eth
# query proposal for: marsproject.eth
# query proposal for: velotoken.eth
# query proposal for: fyooztesting.eth
# query proposal for: matev.eth
# query proposal for: benchmarkprotocol.eth
# query proposal for: maha.eth
# query proposal for: cream-finance.eth
# query proposal for: evoland.eth
# query proposal for: revelationdao.eth
# query proposal for: hoedao.ethquery proposal for: shabushabufi.eth
#
# query proposal for: wise-token.eth
# query proposal for: keepstakers.eth
# query proposal for: santiment.eth
# query proposal for: sportx.eth
# query proposal for: protekt.eth
# query proposal for: as2network.eth
# query proposal for: squirrelcash.eth
# query proposal for: dexg.eth
# query proposal for: yfdaifinance.eth
# query proposal for: grantcomp.eth
# query proposal for: edao.eth
# Error! status code: 429Error! status code: 429
#
# retry after waiting 3s
# retry after waiting 3s
# query proposal for: pegscash.eth
# Error! status code: 429Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
#
# retry after waiting 3s
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: as2network.ethquery proposal for: sportx.eth
#
# query proposal for: dexg.ethquery proposal for: squirrelcash.ethquery proposal for: protekt.eth
#
#
# query proposal for: yfdaifinance.eth
# query proposal for: grantcomp.eth
# query proposal for: edao.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pegscash.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: as2network.eth
# query proposal for: yfdaifinance.eth
# query proposal for: squirrelcash.eth
# query proposal for: protekt.ethquery proposal for: sportx.eth
#
# query proposal for: dexg.ethquery proposal for: grantcomp.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pegscash.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: edao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: as2network.eth
# query proposal for: yfdaifinance.eth
# query proposal for: squirrelcash.eth
# query proposal for: grantcomp.ethquery proposal for: dexg.eth
#
# query proposal for: protekt.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: sportx.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: edao.eth
# query proposal for: pegscash.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: as2network.eth
# query proposal for: yfdaifinance.eth
# query proposal for: squirrelcash.eth
# query proposal for: dexg.ethquery proposal for: protekt.eth
#
# query proposal for: sportx.eth
# query proposal for: grantcomp.eth
# query proposal for: pegs.eth
# query proposal for: gel.dexg.eth
# query proposal for: routerprotocol.eth
# query proposal for: pegscash.eth
# query proposal for: omg.eth
# query proposal for: neverlose.eth
# query proposal for: flexusd.ethquery proposal for: universalcash.eth
#
# query proposal for: prosperso.ethquery proposal for: edao.eth
#
# query proposal for: stakedao.eth
# query proposal for: bangrocks.eth
# query proposal for: basisgold.eth
# query proposal for: typhoon-cash.eth
# query proposal for: pkgtoken.eth
# query proposal for: mstabledao.eth
# query proposal for: okcashlab.eth
# query proposal for: dextfprotocol.eth
# query proposal for: clapfinance.eth
# query proposal for: vicnaum.eth
# query proposal for: armorgov.eth
# query proposal for: pandayield.eth
# query proposal for: earndefi.eth
# query proposal for: bzx.eth
# query proposal for: testmytoken.eth
# query proposal for: defigeek.eth
# query proposal for: stablexfinance.eth
# query proposal for: fyoozapp.eth
# query proposal for: snapshottest.eth
# query proposal for: mushroomsfi.eth
# query proposal for: community.nexusmutual.eth
# query proposal for: vote.airswap.eth
# query proposal for: vote-rinkeby.airswap.eth
# query proposal for: aventus.eth
# query proposal for: metafactory.eth
# query proposal for: kebabfinance.eth
# query proposal for: lido-snapshot.eth
# query proposal for: 1btc.eth
# query proposal for: monsterslayer.eth
# query proposal for: epik.eth
# query proposal for: stabilize-governance.eth
# query proposal for: signal.yam.eth
# query proposal for: gamestopfinance.eth
# query proposal for: basisusd.eth
# query proposal for: opiumprotocol.eth
# query proposal for: gov.dhedge.eth
# query proposal for: kuko.eth
# query proposal for: memefarm.eth
# query proposal for: requestgovernance.eth
# query proposal for: dalmatians.eth
# query proposal for: diadao.eth
# query proposal for: crtfinance.eth
# query proposal for: thegraphnetwork.eth
# query proposal for: kif-gov.eth
# query proposal for: AngelDAO.ethquery proposal for: employmentcommons.eth
#
# query proposal for: ilv.eth
# query proposal for: curefarm.eth
# query proposal for: inversefinance.eth
# query proposal for: mbcore.eth
# query proposal for: tw33t.eth
# query proposal for: marginswap.eth
# query proposal for: gentlemensbank.eth
# query proposal for: stblfund.eth
# query proposal for: migbusiness.eth
# query proposal for: yzydao.eth
# query proposal for: wallstreetbetstoken.eth
# query proposal for: genesis-dao.hopr.eth
# query proposal for: bonfi.eth
# query proposal for: premia.eth
# query proposal for: perlinx.eth
# query proposal for: thefamoustoken.eth
# query proposal for: julswap.eth
# query proposal for: hogefoundation.eth
# query proposal for: alchemistcoin.eth
# query proposal for: optyfi.eth
# query proposal for: spongefinance.eth
# query proposal for: sharedstake.eth
# query proposal for: cafeswapfinance.eth
# query proposal for: stakingcapital.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: saltdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: fraxfinancegovernance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: thefamoustoken.eth
# query proposal for: alchemistcoin.eth
# query proposal for: spongefinance.ethquery proposal for: optyfi.eth
#
# query proposal for: stakingcapital.ethquery proposal for: saltdao.eth
#
# query proposal for: sharedstake.ethquery proposal for: cafeswapfinance.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: fraxfinancegovernance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: thefamoustoken.eth
# query proposal for: alchemistcoin.eth
# query proposal for: spongefinance.eth
# query proposal for: saltdao.eth
# query proposal for: sharedstake.ethquery proposal for: stakingcapital.ethquery proposal for: optyfi.ethquery proposal for: cafeswapfinance.eth
#
#
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: fraxfinancegovernance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: thefamoustoken.eth
# query proposal for: spongefinance.ethquery proposal for: alchemistcoin.eth
#
# query proposal for: stakingcapital.eth
# query proposal for: cafeswapfinance.ethquery proposal for: sharedstake.eth
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: optyfi.eth
# query proposal for: saltdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: fraxfinancegovernance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: thefamoustoken.eth
# query proposal for: cafeswapfinance.eth
# query proposal for: alchemistcoin.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: stakingcapital.eth
# query proposal for: sharedstake.eth
# query proposal for: optyfi.ethquery proposal for: spongefinance.eth
#
# query proposal for: saltdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# Error! status code: 429retry after waiting 3s
#
# retry after waiting 3s
# query proposal for: fraxfinancegovernance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: thefamoustoken.eth
# query proposal for: alchemistcoin.eth
# query proposal for: mstableprotocoldao.eth
# query proposal for: spongefinance.ethquery proposal for: cafeswapfinance.eth
#
# query proposal for: saltdao.eth
# query proposal for: sharedstake.eth
# query proposal for: optyfi.eth
# query proposal for: stakingcapital.eth
# query proposal for: snapshot.floatprotocol.eth
# query proposal for: xmon.eth
# query proposal for: klondike.eth
# query proposal for: arrayfinance.eth
# query proposal for: snxambassador.eth
# query proposal for: eublas.xyz
# query proposal for: thedaotoken.eth
# query proposal for: fraxfinancegovernance.eth
# query proposal for: fundamenta.eth
# query proposal for: ccbig.eth
# query proposal for: blakeburrito.eth
# query proposal for: vsp.eth
# query proposal for: config.airswap.eth
# query proposal for: pancakebunny.eth
# query proposal for: mcl-multiplierfinance.eth
# query proposal for: libertypie.eth
# query proposal for: gnosis.eth
# query proposal for: tastefinance.eth
# query proposal for: shemalefinance.eth
# query proposal for: riseprotocol.eth
# query proposal for: candyfinance.eth
# query proposal for: easybake.eth
# query proposal for: harvestfi.eth
# query proposal for: degentokenfinance.eth
# query proposal for: alpacafinance.eth
# query proposal for: snapshot.paraswap-io.eth
# query proposal for: tokenlon.eth
# query proposal for: visor.eth
# query proposal for: gov.radicle.eth
# query proposal for: magicbalancer.eth
# query proposal for: goatcoin.eth
# query proposal for: uni.meme0xb1.eth
# query proposal for: oracles.opiumprotocol.eth
# query proposal for: zfogg.eth
# query proposal for: alchemixstakers.eth
# query proposal for: tadpolefinance.eth
# query proposal for: bamboodefi.eth
# query proposal for: graphprotocol.eth
# query proposal for: badger.meme0xb1.eth
# query proposal for: alpha.meme0xb1.eth
# query proposal for: rook.meme0xb1.eth
# query proposal for: yax.meme0xb1.eth
# query proposal for: yfl.meme0xb1.eth
# query proposal for: frami.eth
# query proposal for: snowfork.eth
# query proposal for: tracer.eth
# query proposal for: jasonliu.eth
# query proposal for: beatsdao.eth
# query proposal for: ensuser.eth
# query proposal for: spartancouncil.eth
# query proposal for: snxgov.eth
# query proposal for: snxgrants.eth
# query proposal for: ramenswap.eth
# query proposal for: diamondhandsfinance.eth
# query proposal for: emarket.eth
# query proposal for: virtualbacon.eth
# query proposal for: wasabiswap.eth
# query proposal for: pcdai.pooltogether.eth
# query proposal for: daiquilibrium.eth
# query proposal for: fbear.eth
# query proposal for: apoyield.eth
# query proposal for: xcomb.eth
# query proposal for: everframe.eth
# query proposal for: GamyFi.eth
# query proposal for: thanku.eth
# query proposal for: niubiswap.eth
# query proposal for: insuretoken.eth
# query proposal for: midasgold.eth
# query proposal for: ethereum4.eth
# query proposal for: somegreenguy.eth
# query proposal for: rulerprotocol.eth
# query proposal for: biopset.eth
# query proposal for: shoppingio.eth
# query proposal for: tsukidao.eth
# query proposal for: pootogetherbsc.eth
# query proposal for: quickvote.eth
# query proposal for: aqualair.eth
# query proposal for: itam.ethError! status code: 429
#
# retry after waiting 3s
# query proposal for: impossiblefinance.eth
# query proposal for: universalweb.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wasabiswap.eth
# query proposal for: shoppingio.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pootogetherbsc.ethquery proposal for: tsukidao.eth
#
# query proposal for: universalweb.eth
# query proposal for: aqualair.ethquery proposal for: quickvote.ethquery proposal for: impossiblefinance.eth
#
#
# query proposal for: itam.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wasabiswap.eth
# query proposal for: shoppingio.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: impossiblefinance.eth
# query proposal for: pootogetherbsc.eth
# query proposal for: quickvote.eth
# query proposal for: universalweb.ethError! status code: 429
# retry after waiting 3s
#
# query proposal for: itam.eth
# query proposal for: tsukidao.ethError! status code: 429
# retry after waiting 3s
# query proposal for: aqualair.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wasabiswap.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: shoppingio.eth
# query proposal for: impossiblefinance.eth
# query proposal for: pootogetherbsc.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: itam.eth
# query proposal for: tsukidao.ethquery proposal for: aqualair.eth
#
# query proposal for: universalweb.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: quickvote.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wasabiswap.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: shoppingio.eth
# query proposal for: impossiblefinance.eth
# query proposal for: itam.eth
# query proposal for: pootogetherbsc.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: tsukidao.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: universalweb.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: aqualair.eth
# query proposal for: quickvote.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wasabiswap.eth
# query proposal for: mimo.eth
# query proposal for: impossiblefinance.eth
# query proposal for: shoppingio.eth
# query proposal for: irl.eth
# query proposal for: tsukidao.ethquery proposal for: itam.eth
#
# query proposal for: pootogetherbsc.eth
# query proposal for: universalweb.ethquery proposal for: kovan.mimo.eth
#
# query proposal for: kangal.eth
# query proposal for: aqualair.eth
# query proposal for: quickvote.eth
# query proposal for: bsnapshot.eth
# query proposal for: defiville.eth
# query proposal for: laserswap.eth
# query proposal for: gvvalue.eth
# query proposal for: kangal-bsc.eth
# query proposal for: pangolindex.eth
# query proposal for: pooltogether.ethquery proposal for: poolpool.pooltogether.eth
# query proposal for: lok.yieldguild.eth
#
# query proposal for: stimmyio.eth
# query proposal for: bnfyfinance.eth
# query proposal for: realcycloneprotocol.eth
# query proposal for: dozerz.eth
# query proposal for: bingocash.eth
# query proposal for: 12580.eth
# query proposal for: midasdollar.eth
# query proposal for: starthaus.eth
# query proposal for: awsbcommunity.eth
# query proposal for: koios.ethquery proposal for: ballena.eth
#
# query proposal for: unfi.eth
# query proposal for: cryptfi.eth
# query proposal for: latticegov.eth
# query proposal for: pasta.eth
# query proposal for: 🍯dao.eth
# query proposal for: forcedao.eth
# query proposal for: snapshot.rupaya.eth
# query proposal for: bancornetwork.eth
# query proposal for: cyberficommunity.eth
# query proposal for: bval20.bvalosek.eth
# query proposal for: bvalosek.eth
# query proposal for: xfarmer.eth
# query proposal for: elasticdao.eth
# query proposal for: synthereum.eth
# query proposal for: legodao.eth
# query proposal for: iwan.eth
# query proposal for: haykerdao.eth
# query proposal for: cryptokombat.eth
# query proposal for: cover-protocol.eth
# query proposal for: officialoceandao.eth
# query proposal for: aladdindao.eth
# query proposal for: snapshot.nucypherdao.eth
# query proposal for: 88mph.eth
# query proposal for: resistanceio.ethquery proposal for: test.alirun.eth
#
# query proposal for: kimchidao.eth
# query proposal for: poh.eth
# query proposal for: nudao.eth
# query proposal for: apefinance.eth
# query proposal for: haze.eth
# query proposal for: unslashed.eth
# query proposal for: anshiny.eth
# query proposal for: pythostoken.eth
# query proposal for: ilvgov.eth
# query proposal for: ren-project.eth
# query proposal for: stix.eth
# query proposal for: boardroomfi.eth
# query proposal for: comp-vote.eth
# query proposal for: curiovoters.eth
# query proposal for: ybaby.eth
# query proposal for: arcx.eth
# query proposal for: forkenomics.eth
# query proposal for: beetsdao.eth
# query proposal for: council.graphprotocol.eth
# query proposal for: tuskerfinance.eth
# query proposal for: squiggledao.ethquery proposal for: matthewnolan.eth
#
# query proposal for: stonkbase.eth
# query proposal for: maskedofpower.eth
# query proposal for: morphose.eth
# query proposal for: defilabsfoundation.eth
# query proposal for: macaronswap.eth
# query proposal for: levinswap.eth
# Error! status code: 429Error! status code: 429query proposal for: suni.eth
#
#
# retry after waiting 3s
# retry after waiting 3squery proposal for: wallabyfinance.eth
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: berezka.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: maskedofpower.eth
# query proposal for: defilabsfoundation.ethquery proposal for: stonkbase.eth
#
# query proposal for: morphose.eth
# query proposal for: macaronswap.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: suni.eth
# query proposal for: berezka.ethquery proposal for: wallabyfinance.eth
#
# query proposal for: levinswap.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: defilabsfoundation.eth
# query proposal for: stonkbase.eth
# query proposal for: maskedofpower.eth
# query proposal for: morphose.eth
# query proposal for: macaronswap.eth
# Error! status code: 429Error! status code: 429
#
# Error! status code: 429retry after waiting 3sretry after waiting 3s
#
#
# retry after waiting 3s
# query proposal for: suni.eth
# query proposal for: berezka.ethquery proposal for: levinswap.eth
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wallabyfinance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: stonkbase.ethquery proposal for: defilabsfoundation.ethquery proposal for: maskedofpower.eth
#
#
# query proposal for: morphose.eth
# query proposal for: suni.ethquery proposal for: macaronswap.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: berezka.ethquery proposal for: levinswap.eth
#
# query proposal for: wallabyfinance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: stonkbase.eth
# query proposal for: defilabsfoundation.ethquery proposal for: maskedofpower.eth
#
# query proposal for: morphose.eth
# query proposal for: rootkitfinance.eth
# query proposal for: covalenthq.ethquery proposal for: berezka.eth
# query proposal for: resdx.eth
#
# query proposal for: suni.eth
# query proposal for: levinswap.eth
# query proposal for: macaronswap.eth
# query proposal for: wallabyfinance.eth
# query proposal for: usebraintrustropsten.eth
# query proposal for: chanyshev.eth
# query proposal for: sishi.eth
# query proposal for: methodfinance.eth
# query proposal for: pepedontdump.eth
# query proposal for: ethlocal.eth
# query proposal for: kika2021.eth
# query proposal for: shinedao.eth
# query proposal for: compoundgrants.eth
# query proposal for: crypto-corgis.eth
# query proposal for: hash.pob.eth
# query proposal for: recess.eth
# query proposal for: shardingdao.eth
# query proposal for: solos.eth
# query proposal for: geeksg.eth
# query proposal for: m.bsnapshot.eth
# query proposal for: ffdao.eth
# query proposal for: krebit.eth
# query proposal for: fei.eth
# query proposal for: olympusdao.eth
# query proposal for: leafan.eth
# query proposal for: nsure.eth
# query proposal for: adamant.eth
# query proposal for: blockzerolabs.eth
# query proposal for: elastic-vote-sandbox.eth
# query proposal for: igov.eth
# query proposal for: cherryblossomcommunity.eth
# query proposal for: levyathan.eth
# query proposal for: viralata.eth
# query proposal for: creditblockchain.eth
# query proposal for: akropolis.eth
# query proposal for: curadai.eth
# query proposal for: sirenmarkets.eth
# query proposal for: unifundglobal.eth
# query proposal for: slimefinance.eth
# query proposal for: berrydata.eth
# query proposal for: test.pzsm.eth
# query proposal for: axiondao.eth
# query proposal for: dfvindex.eth
# query proposal for: doomies.eth
# query proposal for: basketdao.eth
# query proposal for: brt.otoco.eth
# query proposal for: iotexnetwork.eth
# query proposal for: iftip.eth
# query proposal for: strudel.eth
# query proposal for: 0xdef1.eth
# query proposal for: entropyseeds.eth
# query proposal for: complus.eth
# query proposal for: fera.eth
# query proposal for: aluna.eth
# query proposal for: suprafinance.xyz
# query proposal for: pollo.eth
# query proposal for: hiveshares.eth
# query proposal for: claimxyz.eth
# query proposal for: treedefi.eth
# query proposal for: nervefinance.eth
# query proposal for: pleasrdao.eth
# query proposal for: halodao.eth
# query proposal for: stackerventures.eth
# query proposal for: enigma16.eth
# query proposal for: everipediaiq.eth
# query proposal for: parallaxprotocol.eth
# query proposal for: token.m1guelpf.eth
# query proposal for: ebog.eth
# query proposal for: chrisco.eth
# query proposal for: frictionfinance.eth
# query proposal for: crd.eth
# query proposal for: alend.amun.eth
# query proposal for: shedapp.eth
# query proposal for: uberhaus.eth
# query proposal for: em3dao.eth
# query proposal for: julpad.eth
# query proposal for: hakka.eth
# query proposal for: rallygov.ethquery proposal for: changfan.eth
#
# Error! status code: 429
# retry after waiting 3squery proposal for: waifusiongov.eth
#
# Error! status code: 502
# query proposal for: em3dao.eth
# query proposal for: úrnua.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: chrisco.eth
# query proposal for: shedapp.eth
# query proposal for: julpad.eth
# query proposal for: rallygov.ethquery proposal for: hakka.eth
#
# query proposal for: waifusiongov.ethquery proposal for: changfan.eth
#
# query proposal for: úrnua.eth
# Error! status code: 429query proposal for: em3dao.eth
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: chrisco.ethquery proposal for: shedapp.eth
#
# query proposal for: rallygov.eth
# query proposal for: julpad.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: hakka.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: úrnua.eth
# query proposal for: em3dao.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: waifusiongov.eth
# query proposal for: changfan.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: shedapp.eth
# query proposal for: rallygov.eth
# query proposal for: chrisco.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: julpad.eth
# query proposal for: hakka.ethquery proposal for: em3dao.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: waifusiongov.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: úrnua.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: changfan.ethError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: rallygov.eth
# query proposal for: julpad.ethError! status code: 429
# retry after waiting 3s
# query proposal for: shedapp.eth
#
# query proposal for: chrisco.eth
# query proposal for: em3dao.ethquery proposal for: hakka.eth
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: úrnua.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: waifusiongov.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: changfan.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: rallygov.eth
# query proposal for: julpad.eth
# query proposal for: shedapp.eth
# query proposal for: chrisco.ethquery proposal for: em3dao.ethquery proposal for: hakka.eth
#
#
# query proposal for: kishutoken.eth
# query proposal for: uniq.eth
# query proposal for: úrnua.eth
# query proposal for: waifusiongov.eth
# query proposal for: geometrylabs.eth
# query proposal for: samuv.eth
# query proposal for: zkswapgov.eth
# query proposal for: turpintinz.eth
# query proposal for: shadowpakt.storymode.ethquery proposal for: layercash.eth
#
# query proposal for: tianranzhang.eth
# query proposal for: bsc.bzx.eth
# query proposal for: metacartel.eth
# query proposal for: finnexusbsc.eth
# query proposal for: changfan.eth
# query proposal for: dexfolio.eth
# query proposal for: stakewise.eth
# query proposal for: cryptokekbsc.eth
# query proposal for: dbookplatform.eth
# query proposal for: mithcash2.eth
# query proposal for: stonedefi.eth
# query proposal for: scoobi.eth
# query proposal for: pippi.eth
# query proposal for: dgov.eth
# query proposal for: chainbay.eth
# query proposal for: ethersocks.eth
# query proposal for: nococaine.eth
# query proposal for: creaton.eth
# query proposal for: dogen.eth
# query proposal for: debaseonomics.eth
# query proposal for: klt.eth
# query proposal for: myceliumgrowth.eth
# query proposal for: infinitycrypto.eth
# query proposal for: 0xb1.eth
# query proposal for: shardcoin.eth
# query proposal for: hyruleswap.eth
# query proposal for: rootdraws.eth
# query proposal for: fairsafe.eth
# query proposal for: alexx855.eth
# query proposal for: thunderbirdgov.eth
# query proposal for: belugaprotocol.eth
# query proposal for: crowdex.eth
# query proposal for: joe-defi.eth
# query proposal for: afterparty.eth
# query proposal for: musky.eth
# query proposal for: splitworld.eth
# query proposal for: jitime.eth
# query proposal for: fartoken.eth
# query proposal for: soappunk.eth
# query proposal for: djedi.eth
# query proposal for: lolcat.eth
# query proposal for: justmarketbuy.eth
# query proposal for: ecm.ethquery proposal for: liftkitchen.eth
#
# query proposal for: apeswap-finance.eth
# query proposal for: masknetwork.eth
# query proposal for: losercoin.eth
# query proposal for: gzks.eth
# query proposal for: bsaepfl.eth
# query proposal for: covinu.eth
# query proposal for: boardroomlabs.eth
# query proposal for: mcswagg.eth
# query proposal for: scamily.eth
# query proposal for: polkaflare.eth
# query proposal for: bozo-capital.eth
# query proposal for: tinvdao.eth
# query proposal for: basedloans.eth
# query proposal for: stackervc.eth
# query proposal for: pascall.eth
# query proposal for: xsig.eth
# query proposal for: dgcl.eth
# query proposal for: libertas.eth
# query proposal for: dappchaser.eth
# query proposal for: unigod.storymode.eth
# query proposal for: flygoing.eth
# query proposal for: treatvote.eth
# query proposal for: superfarm.eth
# query proposal for: smoothyfinance.eth
# query proposal for: bpro.eth
# query proposal for: innovationtheory.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dolphincoin.eth
# query proposal for: onepoolfinance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: guaini.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dappchaser.eth
# query proposal for: superfarm.eth
# query proposal for: libertas.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: smoothyfinance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: innovationtheory.ethquery proposal for: bpro.eth
#
# query proposal for: onepoolfinance.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: guaini.ethquery proposal for: dolphincoin.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dappchaser.eth
# query proposal for: superfarm.eth
# query proposal for: libertas.eth
# query proposal for: smoothyfinance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: bpro.eth
# query proposal for: innovationtheory.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: onepoolfinance.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dolphincoin.eth
# query proposal for: guaini.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dappchaser.eth
# query proposal for: superfarm.ethquery proposal for: libertas.eth
#
# query proposal for: smoothyfinance.eth
# query proposal for: innovationtheory.eth
# query proposal for: bpro.ethquery proposal for: onepoolfinance.eth
#
# query proposal for: dolphincoin.eth
# query proposal for: guaini.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# query proposal for: dappchaser.eth
# query proposal for: smoothyfinance.eth
# query proposal for: libertas.eth
# query proposal for: onepoolfinance.eth
# query proposal for: bpro.ethquery proposal for: superfarm.eth
#
# query proposal for: dolphincoin.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: innovationtheory.eth
# query proposal for: guaini.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dappchaser.eth
# query proposal for: smoothyfinance.eth
# query proposal for: libertas.ethquery proposal for: superfarm.eth
#
# query proposal for: bohemiandao.eth
# query proposal for: bpro.eth
# query proposal for: pantherswap.eth
# query proposal for: dolphincoin.eth
# query proposal for: innovationtheory.eth
# query proposal for: guaini.eth
# query proposal for: eth3913.eth
# query proposal for: moonrat.eth
# query proposal for: smoothybsc.eth
# query proposal for: hegic.eth
# query proposal for: bsc.defidolla.eth
# query proposal for: b1mt.eth
# query proposal for: pastadao.eth
# query proposal for: buckswap.eth
# query proposal for: flydao.eth
# query proposal for: blxpr.eth
# query proposal for: getsafex.eth
# query proposal for: buger.eth
# query proposal for: onepoolfinance.eth
# query proposal for: orangecats.eth
# query proposal for: alchemistdefi.eth
# query proposal for: gaiadao.eth
# query proposal for: ens.eth
# query proposal for: hodorfi.eth
# query proposal for: mars26.eth
# query proposal for: feederfinance.eth
# query proposal for: acoconutbsc.eth
# query proposal for: buche.eth
# query proposal for: meowdao.eth
# query proposal for: porkswap.eth
# query proposal for: bscbadger.eth
# query proposal for: flashcommunity.eth
# query proposal for: pupperdao.eth
# query proposal for: adventurelandfinance.eth
# query proposal for: banklessvault.eth
# query proposal for: fingerprints.eth
# query proposal for: spookyswap.eth
# query proposal for: elasticbnb.eth
# query proposal for: alwayshasbeen.eth
# query proposal for: ampleforthorg.eth
# query proposal for: frogdaogov.eth
# query proposal for: vasily.eth
# query proposal for: snapshotesting.xyz
# query proposal for: astromoon.eth
# query proposal for: cryptovibetribe.eth
# query proposal for: altrucoin.eth
# query proposal for: polisdao.eth
# query proposal for: govrn-test.govrn.eth
# query proposal for: xiaoyuwan.eth
# query proposal for: blackboxart.eth
# query proposal for: fontcommunity.eth
# query proposal for: troylee.eth
# query proposal for: wanxutao.eth
# query proposal for: libertasdex.eth
# query proposal for: vitalik.storymode.eth
# query proposal for: crisisdao.eth
# query proposal for: spiritswap.eth
# query proposal for: poodltoken.eth
# query proposal for: partydao.eth
# query proposal for: vbswap.eth
# query proposal for: cryptodigger.eth
# query proposal for: becoswap.eth
# query proposal for: apescape.eth
# query proposal for: rotomoon.eth
# query proposal for: cccccccc.eth
# query proposal for: icap-governance.eth
# query proposal for: deversifi.eth
# query proposal for: recharge-finance.eth
# query proposal for: gmetoken.eth
# query proposal for: cdtk.computerdata.eth
# query proposal for: 0xdollar
# query proposal for: 7add
# query proposal for: achievmintry
# query proposal for: acryptos
# query proposal for: alex
# query proposal for: alpha-bsc
# query proposal for: alpha-ethereum
# query proposal for: ampleforth
# query proposal for: amplegold
# query proposal for: amplesense
# query proposal for: anj
# query proposal for: anjmol
# query proposal for: aragon
# query proposal for: aragonchina
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: arckyf
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: alpha-bscquery proposal for: alpha-ethereum
#
# query proposal for: anj
# query proposal for: anjmol
# query proposal for: aragon
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: aragonchinaquery proposal for: amplesense
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: arckyf
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: alex
# Error! status code: 429
# retry after waiting 3s
# query proposal for: alpha-ethereum
# query proposal for: alpha-bsc
# query proposal for: anj
# query proposal for: aragon
# Error! status code: 429
# retry after waiting 3s
# ...
# query proposal for: topcorn.eth
# query proposal for: one22.eth
# query proposal for: one33.eth
# query proposal for: one55.eth
# query proposal for: fly66.eth
# query proposal for: usdm.marsecosystem.com
# query proposal for: goozeone.ethError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: melomance.eth
# query proposal for: topcorn.ethquery proposal for: bossdaovc.ethquery proposal for: one55.eth
#
#
# query proposal for: usdm.marsecosystem.com
# query proposal for: one33.eth
# query proposal for: fly66.eth
# query proposal for: one22.ethquery proposal for: goozeone.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: bossdaovc.eth
# query proposal for: topcorn.eth
# query proposal for: melomance.eth
# query proposal for: one33.eth
# query proposal for: one55.eth
# query proposal for: fly66.eth
# query proposal for: usdm.marsecosystem.com
# Error! status code: 429
# retry after waiting 3s
# query proposal for: goozeone.eth
# query proposal for: one22.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: bossdaovc.eth
# query proposal for: topcorn.eth
# query proposal for: melomance.eth
# query proposal for: one33.eth
# query proposal for: one55.ethquery proposal for: fly66.eth
#
# query proposal for: usdm.marsecosystem.com
# query proposal for: one22.ethquery proposal for: goozeone.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: melomance.ethquery proposal for: bossdaovc.eth
#
# query proposal for: one33.ethquery proposal for: topcorn.eth
#
# query proposal for: one55.eth
# query proposal for: usdm.marsecosystem.com
# query proposal for: fly66.eth
# query proposal for: ozean.eth
# query proposal for: goozeone.eth
# query proposal for: proofofalienlife.eth
# query proposal for: zkrollub.eth
# query proposal for: 561256.eth
# query proposal for: one22.eth
# query proposal for: 098336.eth
# Error! status code: 504
# query proposal for: one22.eth
# query proposal for: afshan1190.eth
# query proposal for: karibuu.eth
# query proposal for: lucidhoang.ethquery proposal for: eth541.eth
#
# query proposal for: timimi.eth
# query proposal for: wireshape-dao.eth
# query proposal for: gobblerunion.eth
# query proposal for: stitched.eth
# query proposal for: buidlhere.eth
# query proposal for: permissionassociation.eth
# query proposal for: emprendedao.eth
# query proposal for: bedrockprotocol.eth
# query proposal for: dao-research-institute.eth
# query proposal for: coincapital.eth
# query proposal for: web3dao.eth
# query proposal for: camelia.eth
# query proposal for: cosmopolitandao.eth
# query proposal for: tannid.eth
# query proposal for: phraco.ethquery proposal for: yooshicat.eth
#
# query proposal for: monsterswamp.eth
# query proposal for: sanshudao.eth
# query proposal for: iamnotontherun.eth
# query proposal for: plusdao.eth
# query proposal for: artis-dao.eth
# query proposal for: chenxiaomao.eth
# query proposal for: sandclockdao.eth
# query proposal for: gridcraft.eth
# query proposal for: dickkingz.eth
# query proposal for: gangster4462.eth
# query proposal for: capmus.eth
# query proposal for: tris.eth
# query proposal for: sbwcdao.eth
# query proposal for: kelewh.eth
# query proposal for: wolfiland.ethquery proposal for: abenben.eth
#
# query proposal for: oneordina2.eth
# query proposal for: japanictdao.eth
# query proposal for: abing.eth
# query proposal for: varmeta.eth
# query proposal for: torahdao.ethquery proposal for: poodlefinetwork.eth
#
# query proposal for: tim.umbra.eth
# query proposal for: theharborfi.eth
# query proposal for: nine-chronicles-dao.eth
# query proposal for: ikb.mitchellfchan.eth
# query proposal for: royalelastics.eth
# query proposal for: collectoooors.eth
# query proposal for: alitasusme.eth
# query proposal for: brittm.eth
# query proposal for: allstardao.eth
# query proposal for: rucapen.eth
# query proposal for: pacy.eth
# query proposal for: mashiroai.eth
# query proposal for: wolfimemes.eth
# query proposal for: defedcommunity.eth
# query proposal for: 0xkang.eth
# query proposal for: qatardev.eth
# query proposal for: cuneyteren.eth
# query proposal for: jntaoli.eth
# query proposal for: k0011.eth
# query proposal for: kgt.eth
# query proposal for: itchyhands.eth
# query proposal for: kodaoio.eth
# query proposal for: kobzar.eth
# query proposal for: qtcon.eth
# query proposal for: eyeverse.ethquery proposal for: staderdao.eth
#
# query proposal for: keyship.eth
# query proposal for: 0xddc.eth
# query proposal for: lapalmafc.eth
# query proposal for: cartoonsdao.eth
# query proposal for: anontreasury.eth
# query proposal for: superversedao.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: karmananny.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: qtcon.eth
# query proposal for: staderdao.eth
# query proposal for: keyship.ethquery proposal for: anontreasury.ethquery proposal for: cartoonsdao.eth
#
#
# query proposal for: superversedao.ethquery proposal for: lapalmafc.ethquery proposal for: 0xddc.eth
#
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: karmananny.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3sError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3sError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# query proposal for: qtcon.eth
# query proposal for: staderdao.eth
# query proposal for: keyship.eth
# query proposal for: anontreasury.ethquery proposal for: cartoonsdao.ethquery proposal for: lapalmafc.eth
#
#
# query proposal for: superversedao.ethquery proposal for: 0xddc.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: karmananny.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: qtcon.ethquery proposal for: staderdao.eth
#
# query proposal for: lapalmafc.eth
# query proposal for: 0xddc.ethquery proposal for: keyship.eth
# query proposal for: superversedao.eth
#
# query proposal for: cartoonsdao.eth
# query proposal for: anontreasury.eth
# query proposal for: karmananny.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: qtcon.eth
# query proposal for: staderdao.eth
# query proposal for: lapalmafc.ethquery proposal for: cartoonsdao.ethquery proposal for: keyship.eth
# query proposal for: anontreasury.eth
#
#
# query proposal for: 0xddc.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: karmananny.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429query proposal for: superversedao.eth
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3sError! status code: 429
# retry after waiting 3s
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: qtcon.eth
# query proposal for: staderdao.eth
# query proposal for: lapalmafc.ethquery proposal for: anontreasury.eth
#
# query proposal for: 0xddc.eth
# query proposal for: keyship.ethquery proposal for: cartoonsdao.eth
#
# query proposal for: 999vote.eth
# query proposal for: 10kvote.eth
# query proposal for: karmananny.ethquery proposal for: blockandwhite.eth
#
# query proposal for: legendarylibr.eth
# query proposal for: bocsmetaverse.eth
# query proposal for: konra.eth
# query proposal for: superversedao.eth
# query proposal for: sexly.eth
# query proposal for: 0x116699.eth
# query proposal for: inv3stdao.eth
# query proposal for: worldtreenetwork.eth
# query proposal for: neofantasydao.eth
# query proposal for: playsation.eth
# query proposal for: streetrunnner.ethquery proposal for: gyozatoken.eth
#
# query proposal for: mafor.eth
# query proposal for: collectibleavatarsdao.eth
# query proposal for: buddabearsnft.eth
# query proposal for: shibasociety.eth
# query proposal for: pauaxyz.eth
# query proposal for: pitpa.eth
# query proposal for: volatilityprotocol.eth
# query proposal for: 0x13b.eth
# query proposal for: 1cookies.eth
# query proposal for: cttoken.eth
# query proposal for: rkyoung.eth
# query proposal for: xyq888.eth
# query proposal for: protectyourprivatekey.eth
# query proposal for: cxlive.eth
# query proposal for: vickkyydhakad.eth
# query proposal for: bruhpillsdao.eth
# query proposal for: akharito.eth
# query proposal for: korbievote.eth
# query proposal for: starseeds-dao.eth
# query proposal for: cairofinance.eth
# query proposal for: jordon23.eth
# query proposal for: 753815.eth
# query proposal for: kayci.eth
# query proposal for: shimianying.eth
# query proposal for: kudojimmy.eth
# query proposal for: 234188.eth
# query proposal for: cozdrowe.eth
# query proposal for: a.51nft.eth
# query proposal for: hgame.eth
# query proposal for: chaintool.eth
# query proposal for: repudao.eth
# query proposal for: radiativeforcing.eth
# query proposal for: beingujjwal.eth
# query proposal for: radioreum.eth
# query proposal for: sthorm.eth
# query proposal for: launchzoneann.eth
# query proposal for: moonrockdao.eth
# query proposal for: vangadao.eth
# query proposal for: gauthi3r.eth
# query proposal for: ecosystemx.eth
# query proposal for: duckdrop.eth
# query proposal for: 718l.ethquery proposal for: 800iq.eth
#
# query proposal for: chainosdao.eth
# query proposal for: criptian.ethquery proposal for: boravoting.eth
#
# query proposal for: arantuil.eth
# query proposal for: artarie.eth
# query proposal for: 0x88188.eth
# query proposal for: apefirstddlater.eth
# query proposal for: adamilenich.eth
# query proposal for: dao-anytype.eth
# query proposal for: fasttool.eth
# query proposal for: basedghouls.eth
# query proposal for: 0xjee.eth
# query proposal for: dipankarbahalia.eth
# query proposal for: tutsy.eth
# query proposal for: ronaldo2022.eth
# query proposal for: hloo007.eth
# query proposal for: altxnft.eth
# query proposal for: tonop.eth
# query proposal for: noxbeyond.eth
# query proposal for: curateweb3.eth
# query proposal for: wenlambo.finance
# query proposal for: momiyamashodai.eth
# query proposal for: kswdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429Error! status code: 429
# retry after waiting 3s
#
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dipankarbahalia.eth
# query proposal for: curateweb3.eth
# query proposal for: tonop.ethquery proposal for: noxbeyond.ethquery proposal for: ronaldo2022.eth
#
#
# query proposal for: wenlambo.finance
# Error! status code: 429
# retry after waiting 3s
# query proposal for: kswdao.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: momiyamashodai.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pitpa.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dipankarbahalia.eth
# query proposal for: curateweb3.eth
# query proposal for: ronaldo2022.eth
# query proposal for: tonop.eth
# query proposal for: wenlambo.finance
# query proposal for: noxbeyond.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: kswdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pitpa.ethquery proposal for: momiyamashodai.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dipankarbahalia.eth
# query proposal for: curateweb3.eth
# query proposal for: ronaldo2022.eth
# query proposal for: wenlambo.finance
# Error! status code: 429
# retry after waiting 3s
# query proposal for: tonop.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: noxbeyond.eth
# query proposal for: kswdao.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: pitpa.eth
# query proposal for: momiyamashodai.eth
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dipankarbahalia.eth
# query proposal for: ronaldo2022.eth
# Error! status code: 429
# retry after waiting 3s
# query proposal for: wenlambo.financequery proposal for: tonop.ethquery proposal for: curateweb3.eth
#
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: noxbeyond.eth
# query proposal for: pitpa.eth
# query proposal for: kswdao.ethquery proposal for: momiyamashodai.eth
#
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# Error! status code: 429
# retry after waiting 3s
# query proposal for: dipankarbahalia.eth
# query proposal for: ronaldo2022.eth
# query proposal for: tonop.eth
# query proposal for: curateweb3.eth
# query proposal for: wenlambo.finance
# query proposal for: noxbeyond.ethquery proposal for: pitpa.eth
#
# query proposal for: momiyamashodai.eth
# query proposal for: kswdao.eth

# %%
# get number of proposals per space
df_proposals_grouped = df_proposals.groupby(by=["space_id"]).count().sort_values(['id'],ascending=False)
df_proposals_grouped[df_proposals_grouped['id']>=10]

# %% [markdown]
# # 4. Get votes information
#
#
# The following function retrieves all votes for a give proposal.

# %%
# definition of get_votes function
# (with exception handling)

def get_votes(proposal_id):
    """ this function retrieves all votes for a given proposal
    :param: proposal_id: ID of a snapshot proposal
    returns: list of dictionaries 
    """

    # init list that stores all votes dicts and is returned later
    votes_dict_list = []

    # import libraries
    import requests
    import json
    import time

    #define query string
    query = """ {
                votes (
                    first: 1000000
                    skip: 0
                    where: {
                    proposal: "%s"
                    }
                    orderBy: "created",
                    orderDirection: desc
                ) {
                    id
                    voter
                    vp
                    vp_by_strategy
                    vp_state
                    created
                    proposal {
                    id
                    }
                    choice
                    space {
                    id
                    }
                }
                } """ % (proposal_id)


    # API query routine
    url = 'https://hub.snapshot.org/graphql'


    # try loop
    try: 
        r = requests.post(url, json={'query': query})

        r.raise_for_status()

        if r.status_code == 200: 
            r_dict = json.loads(r.text)

            # loop through votes and store variables in a dict
            for vote in r_dict["data"]["votes"]:

                vote_dict = {}
                vote_dict["voter_proposal_id"] = vote["voter"]+"&&"+vote["proposal"]["id"]
                vote_dict["voter_id"] = vote["voter"]
                vote_dict["proposal_id"] = vote["proposal"]["id"]
                vote_dict["vp"] = vote["vp"]
                vote_dict["vp_by_strategy"] = vote["vp_by_strategy"]
                vote_dict["vp_state"] = vote["vp_state"]
                vote_dict["created"] = vote["created"]
                vote_dict["choice"] = vote["choice"]
                vote_dict["space_id"] = vote["space"]["id"]
                
                # append dict to the list of dicts
                votes_dict_list.append(vote_dict)
        else:
            print("Error message: " + str(r.status_code) + " @proposal: "+ str(proposal_id))

            if r.status_code == 429:
                # wait 5s and retry
                print("Retry after 5s")
                time.sleep(5)
                get_votes(proposal_id)


    except requests.exceptions.HTTPError as e:
        # Maybe set up for a retry, or continue in a retry loop
        print("HTTPError")
        print(e)
        print("Error at proposal: "+ proposal_id)
        print("TooManyRedirects: waiting some seconds before retry")
        time.sleep(5)
        get_votes(proposal_id)

    except requests.exceptions.Timeout as e:
    # Maybe set up for a retry, or continue in a retry loop
        print("Timeout")
        print(e)
        print("Error at proposal: "+ proposal_id)

    except requests.exceptions.ConnectionError as e:
    # Maybe set up for a retry, or continue in a retry loop
        print("ConnectionError")
        print(e)
        print("Error at proposal: "+ proposal_id)


    except requests.exceptions.TooManyRedirects as e:
        # Tell the user their URL was bad and try a different one
        print("TooManyRedirects: wait some seconds and restart")
        print(e)
        print("Error at proposal: "+ proposal_id)
        time.sleep(5)
        get_votes(proposal_id)


    except requests.exceptions.RequestException as e:
        # catastrophic error. bail.
        print(e)
        print("Error at proposal: "+ proposal_id)

    # return the final list of dicts
    return votes_dict_list

# %%
# creat multithread function for votes API call

def multithread_get_votes(prop_list):
    """
    this function splits to task to query the votes for all proposals among a number of workers
    :param: prop_list: list of snapshot proposal IDs
    return: list of votes dicts for all proposals
    """

    # import libraries
    import requests
    import json
    import time
    from concurrent.futures import ThreadPoolExecutor, as_completed


    # initiate vote list to be filled 
    nested_votes_dict_list = []
    votes_dict_list = []

    # define a runner that splits up the task among a number of works
    def runner():
        threads= []
        with ThreadPoolExecutor(max_workers=2) as executor: # before the rate limit you could use up to 10 workers w/o 429 errors. 
            for proposal_id in prop_list:

                threads.append(executor.submit(get_votes, proposal_id))
                
                
            for task in as_completed(threads):
                nested_votes_dict_list.append(task.result())   

    # call the runner
    runner()

    # loop through nested list and flatten it
    for dict_list in nested_votes_dict_list:

        for votes_dict in dict_list:

            votes_dict_list.append(votes_dict)

    # return the final list of all votes dicts
    return votes_dict_list

# %% [markdown]
# #### Get all votes (multithread)

# %%
# load proposals from disk if necessary
#df_proposals = pd.read_csv('snapshot_proposals.csv',  sep=";") 

votes_dict_list = []

# create chunks to prevent API limit
proposal_chunks = [df_proposals["id"][x:x+6000] for x in range(0, len(df_proposals["id"]), 6000)]

# %%
# check number of chunks 

#votes_dict_list_chunk1 = multithread_get_votes(proposal_chunks[0])
votes_dict_list_chunk2 = multithread_get_votes(proposal_chunks[1])
votes_dict_list_chunk3 = multithread_get_votes(proposal_chunks[2])
votes_dict_list_chunk4 = multithread_get_votes(proposal_chunks[3])
votes_dict_list_chunk5 = multithread_get_votes(proposal_chunks[4])
votes_dict_list_chunk6 = multithread_get_votes(proposal_chunks[5])
votes_dict_list_chunk7 = multithread_get_votes(proposal_chunks[6])
votes_dict_list_chunk8 = multithread_get_votes(proposal_chunks[7])
votes_dict_list_chunk9 = multithread_get_votes(proposal_chunks[8])
votes_dict_list_chunk10 = multithread_get_votes(proposal_chunks[9])
votes_dict_list_chunk11 = multithread_get_votes(proposal_chunks[10])

# %%
votes_dict_list_chunk1 = multithread_get_votes(proposal_chunks[0])

df_votes_dict_list_chunk1 = pd.DataFrame(votes_dict_list_chunk1)
df_votes_dict_list_chunk1.to_csv('votes_dict_list_chunk1.csv', index=False, sep=";")
# Out:
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: Qma7L1cNfLdLZJG6UoVowsCrQ39dvQ8sZMkEd7vfNdBpkH
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmTBoSv6LeVUBJuXZx38u85DWbSDw3jXNFmvf1LjL5K4DZ
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmZCYGXcmamCajfr6BVxPfUgCgbJrBucDVUfVFoLfpoASP
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: Qma7L1cNfLdLZJG6UoVowsCrQ39dvQ8sZMkEd7vfNdBpkH
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmTBoSv6LeVUBJuXZx38u85DWbSDw3jXNFmvf1LjL5K4DZ
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmZCYGXcmamCajfr6BVxPfUgCgbJrBucDVUfVFoLfpoASP
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: Qma7L1cNfLdLZJG6UoVowsCrQ39dvQ8sZMkEd7vfNdBpkH
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmTBoSv6LeVUBJuXZx38u85DWbSDw3jXNFmvf1LjL5K4DZ
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmZCYGXcmamCajfr6BVxPfUgCgbJrBucDVUfVFoLfpoASP
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: Qma7L1cNfLdLZJG6UoVowsCrQ39dvQ8sZMkEd7vfNdBpkH
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmTBoSv6LeVUBJuXZx38u85DWbSDw3jXNFmvf1LjL5K4DZ
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: QmZCYGXcmamCajfr6BVxPfUgCgbJrBucDVUfVFoLfpoASP
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x5daa2970fad09e56856648af7b51a94b6ee6ea9f10aaa57e5b82bac1d74c525b
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x4fe5bb66fb43b0a61376b2173d85a39df3f4b28131995674161072e2c1320ade
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x63ed780a7a73d69951602ec74f11d2ccabb92db505ccb8404d2e58b97e9909f4
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x5daa2970fad09e56856648af7b51a94b6ee6ea9f10aaa57e5b82bac1d74c525b
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x4fe5bb66fb43b0a61376b2173d85a39df3f4b28131995674161072e2c1320ade
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x63ed780a7a73d69951602ec74f11d2ccabb92db505ccb8404d2e58b97e9909f4
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x4fe5bb66fb43b0a61376b2173d85a39df3f4b28131995674161072e2c1320adeHTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
#
# Error at proposal: 0x5daa2970fad09e56856648af7b51a94b6ee6ea9f10aaa57e5b82bac1d74c525b
# TooManyRedirects: wait some seconds and restart
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x63ed780a7a73d69951602ec74f11d2ccabb92db505ccb8404d2e58b97e9909f4
# TooManyRedirects: wait some seconds and restart
# HTTPError
# 429 Client Error: Too Many Requests for url: https://hub.snapshot.org/graphql
# Error at proposal: 0x
df_votes_dict_list_chunk9 = pd.DataFrame(votes_dict_list_chunk9)
df_votes_dict_list_chunk9.to_csv('votes_dict_list_chunk9.csv', index=False, sep=";")

# %%
votes_dict_list_chunk10 = multithread_get_votes(proposal_chunks[9])

df_votes_dict_list_chunk10 = pd.DataFrame(votes_dict_list_chunk10)
df_votes_dict_list_chunk10.to_csv('votes_dict_list_chunk10.csv', index=False, sep=";")

# %%
votes_dict_list_chunk11 = multithread_get_votes(proposal_chunks[10])

df_votes_dict_list_chunk11 = pd.DataFrame(votes_dict_list_chunk11)
df_votes_dict_list_chunk11.to_csv('votes_dict_list_chunk11.csv', index=False, sep=";")

# %%
chunk_lists = [votes_dict_list_chunk1, votes_dict_list_chunk2, votes_dict_list_chunk3, votes_dict_list_chunk4, votes_dict_list_chunk5, votes_dict_list_chunk6, votes_dict_list_chunk7, votes_dict_list_chunk8, votes_dict_list_chunk9, votes_dict_list_chunk10, votes_dict_list_chunk11]

votes_dict_list = []

for c_list in chunk_lists:
    for vote in c_list:
        votes_dict_list.append(vote)

len(votes_dict_list)
# Out:
# 5774011

# %%
df_votes = pd.DataFrame(votes_dict_list)

# save data as csv
df_votes.to_csv('snapshot_votes_nov2022.csv', index=False, sep=";")

# %% [markdown]
# # 5. Get follower information
#
# The following function retrieves all followers for a give space.

# %%
# definition of get_votes function 

def get_followers(init_skip, follower_query_limit):
    """
    this function loops through range of following relationship and return the data
    :param: init_skip: integer - the start value of the range
    :param: follower_query_limit: integer - the end of the range to be queried
    returns: list of dicts containing information about the follower relationship
    """

    # import libraries
    import requests
    import json
    import time

    # init list to store all dicts
    follow_dict_list = []

    # loop through range of following relationships
    while init_skip <= follower_query_limit:
        
        # define query string
        query = """ {
                    follows(
                        first: 1000,
                        skip: %s
                    ) {
                        follower
                        space {
                        id
                        }
                        created
                    }
                    } """ % (str(init_skip))

        # API request routine
        url = 'https://hub.snapshot.org/graphql'
        r = requests.post(url, json={'query': query})
        if r.status_code == 200: 
            r_dict = json.loads(r.text)
            r_dict

            # loop through results and store the data in a dict
            for follow in r_dict["data"]["follows"]:
                follow_dict = {}
                follow_dict["follow_id"] = follow["follower"]+"&&"+follow["space"]["id"]
                follow_dict["follower_id"] = follow["follower"]
                follow_dict["space_id"] = follow["space"]["id"]
                follow_dict["created"] = follow["created"]
                
                # append follow list with follow dict
                follow_dict_list.append(follow_dict)

        else: 
            print("Error message: " + str(r.status_code))
            if r.status_code == 429:
                print("Waiting 5s before retry")
                time.sleep(5)
                get_followers(init_skip, follower_query_limit)
            else:
                print("No retry possible")


        # increment skip value
        init_skip += 1000

    # return final list of follow dicts
    return follow_dict_list

# %%
# creat multithread function for followers API call

def multithread_get_followers(number_of_follows_to_query, workers):
    """
    this function splits up the task to retrieve all following relationships among a number of workers
    :param number_of_follows_to_query: integer indicating the number of following relationships to be queried
    :param workers: integer that indicates the number of works that split up the task
    :return: list of dicts of all following relationships
    """
    
    import requests
    import numpy as np
    from concurrent.futures import ThreadPoolExecutor, as_completed


    # split the query space into multithread tasks
    task_size = number_of_follows_to_query/workers

    skip_start = np.arange(0, number_of_follows_to_query, task_size).tolist()
    skip_end = np.arange(task_size, number_of_follows_to_query+task_size, task_size).tolist()

    skip_list = list(zip(skip_start, skip_end))


    # initiate vote list to be filled 
    nested_followers_dict_list = []
    followers_dict_list = []

    
    def runner():
        threads= []
        with ThreadPoolExecutor(max_workers=workers) as executor: #more than 10 workers results in significant more 429 errors
            for skip in skip_list:
                threads.append(executor.submit(get_followers, int(skip[0]), int(skip[1])))

            for task in as_completed(threads):
                nested_followers_dict_list.append(task.result())    
        
    runner()

    # loop through nested list and flatten it
    for dict_list in nested_followers_dict_list:

        for follower_dict in dict_list:

            followers_dict_list.append(follower_dict)


    # filter unique follows ?

    return followers_dict_list

# %% [markdown]
# #### Get all follows

# %%
follower_dict_list = multithread_get_followers(2000000, 1)

# %%
df_follows  = pd.DataFrame(follower_dict_list)
df_follows.to_csv('snapshot_follows.csv', index=False, sep=";")

# %%
follower_dict_list = multithread_get_followers(1100000, 10)

# save the follows as csv file
#df_follows  = pd.DataFrame(follower_dict_list)
#df_follows.to_csv('snapshot_follows.csv', index=False, sep=";")


# read file from backup 
#df_follows = pd.read_csv('snapshot_followers.csv',  sep=";")

# %%
# size of follows df
len(df_followers)

# unique follower addresses
len(df_followers["follower_id"].unique())

df_follows_grouped = df_followers.groupby(by=["space_id"]).count().sort_values(['follower_id'],ascending=False)

df_follows_grouped_mostused = df_follows_grouped[df_follows_grouped['follower_id']>=50]
# Out:
# 1085224

# %% [markdown]
# # 6. Get user information (not relevant)
#
#
# The following function retrieves all user information for a given user address.

# %%
# definition of get_votes function

def get_user_info(user_id):

    query = """ {
                    users(first: 10, where: { id: "%s" }) {
                        id
                        name
                        about
                        avatar
                    }
                    } """ % (user_id)



    url = 'https://hub.snapshot.org/graphql'
    r = requests.post(url, json={'query': query})
    print(r.status_code)
    r_dict = json.loads(r.text)

    return r_dict["data"]["users"][0]

# %%
get_user_info("0xeF8305E140ac520225DAf050e2f71d5fBcC543e7")
# Out:
# 200
# {'id': '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#  'name': 'Fabien!',
#  'about': 'The less code you use, the less there is to break',
#  'avatar': 'ipfs://QmdR1QWmDxYTwoDo2hp9N5iGEMHKxPH2LyhE4ACkTndn84'}

# %% [markdown]
# # 7. Create a SQLite database to store the data
#
# The database has 4 different tables:
#
# - Spaces (PK: space_id FK: follower_id)
# - Proposals (PK: proposal_id FK: space_id)
# - Votes (PK: vote_id  FK: space_id, proposal_id)
# - Followers (PK: follower_id FK:space_id)
# - User (PK/FK: follower_id )

# %%
# function that allows to create a new database

def create_data_base(db_file):
    """ create a database connection to a SQLite database 
    :param db_file: path to data base file"""

    # import libraries
    import sqlite3
    from sqlite3 import Error

    # create a new connection
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print("db successfully create; sqlite version: "+sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()

# %%
# call the function
#create_data_base(r"snapshot_sqlite.db")

# %%
# function that creates a connection to the database

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return conn: Connection object or None
    """

    # import libraries
    import sqlite3
    from sqlite3 import Error

    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print("successfully connected to the db")
        return conn
    except Error as e:
        print(e)

    return conn

# %%
# function that closes the connection to the database

def close_conn(conn):
    """ this function takes a connection to a db as argument and closes it
    :param conn: Connection object
    """

    # import libraries
    import sqlite3
    from sqlite3 import Error

    # close conncetion
    conn.close()
    print("Connection has been closed")

# %% [markdown]
# ## 7.1 Create tables

# %%
# function that creates a new table 

def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    """

    # import libraries
    import sqlite3
    from sqlite3 import Error

    try:
        c = conn.cursor()
        c.execute(create_table_sql)

        
    except Error as e:
        print(e)

# %%
# define a function that creates all tables

def create_all_tables(db_file, create_table_queries):
    """ this function creates all tables from a list of create table queries 
    :param db_file: path of the data base file
    :param create_table_queries: a list of CREATE TABLE statement
    :return:
    """
    # import libraries
    import sqlite3
    from sqlite3 import Error

    # create a connection the the data base file
    conn = create_connection(db_file)

    # create tables
    if conn is not None:

        for table in create_table_queries:

        # create projects table
            create_table(conn, table)
            print("table created")

        # commit changes 
        conn.commit()

        # close the connection to the data base
        close_conn(conn)
    else:
        print("Error! cannot create the database connection.")

# %%
# define create table queries

# create spaces table
create_spaces_table = """CREATE TABLE IF NOT EXISTS spaces (
	                     space_id text PRIMARY KEY,
						 space_name text,
						 about text,
						 network integer,
						 symbol text,
						 number_of_strategies integer,
						 strategies_list text,
						 number_of_admins integer,
						 admins text,
						 number_of_members integer,
						 member_list text,
						 filters_minScore text,
						 filters_onlyMembers text,
						 plugins text
                        );
                      """

# create proposals table
create_proposals_table = """CREATE TABLE IF NOT EXISTS proposals (
						 space_id text, 
						 space_name text,
						 proposal_id text PRIMARY KEY,
						 title text,
						 body text,
						 choices text,
						 start integer,
						 end integer,
						 snapshot text,
						 state text,
						 scores text,
						 scores_by_strategy text,
						 scores_total  text,
						 scores_updated text,
						 author text
                        );
                      """

# create votes table
create_votes_table = """CREATE TABLE IF NOT EXISTS votes (
	                     voter_proposal_id text PRIMARY KEY,
						 voter text,
						 proposal_id text,
						 vp text,
						 vp_by_strategy text,
						 vp_state text,
						 created text,
						 choice text,
						 space_id text
                        );
                      """

# create follows table
create_follows_table = """CREATE TABLE IF NOT EXISTS follows (
	                     follow_id text text PRIMARY KEY,
	                     follower_id text NOT NULL,
	                     space_id text,
	                     created integer
                        );
                      """

# create users table
create_users_table = """CREATE TABLE IF NOT EXISTS users (
	                     user_id text PRIMARY KEY,
	                     about text,
	                     avatar text
                        );
                      """


create_table_queries = [create_spaces_table, create_proposals_table, create_votes_table, create_follows_table, create_users_table]




drop_spaces_table = """DROP TABLE spaces"""

drop_proposals_table = """DROP TABLE proposals"""

drop_votes_table = """DROP TABLE votes"""

drop_follows_table = """DROP TABLE follows"""

drop_users_table = """DROP TABLE users"""


drop_table_queries = [drop_spaces_table, drop_proposals_table, drop_votes_table, drop_follows_table, drop_users_table]

# %%
# create all tables by calling the create table function

create_all_tables(r"snapshot_sqlite_nov2022.db", create_table_queries)
# Out:
# successfully connected to the db
# table created
# table created
# table created
# table created
# table created
# Connection has been closed

# %%
# function that drops a table 

def drop_table(conn, drop_table_sql):
    """ drop a table from the drop_table_sql statement
    :param conn: Connection object
    :param drop_table_sql: a DROP TABLE statement
    """

    # import libraries
    import sqlite3
    from sqlite3 import Error

    try:
        c = conn.cursor()
        c.execute(drop_table_sql)
        conn.commit()

        print("Table has been dropped")

        # close the connection to the data base
        close_conn(conn)

        
        
    except Error as e:
        print(e)

# %%
# drop_table(create_connection(r"snapshot_sqlite.db"), drop_follows_table)
# Out:
# successfully connected to the db
# Connection has been closed
# Table has been dropped

# %% [markdown]
# ## 7.2 Insert data into the tables

# %% [markdown]
# #### 7.2.1 Insert into spaces table

# %%
# insert all spaces into spaces table

def insert_spaces(spaces_dict_list):
    """
    This function connects to the snapshot_sqlite database and inserts all space into the spaces table
    :param spaces_dict_list: list of dicts
    """

    # creat connection to the data base
    conn = create_connection( r"snapshot_sqlite_nov2022.db")
    cur = conn.cursor()

    # loop through dicts in dict list and insert them into the data base
    for space_dict in spaces_dict_list:
        space_values = list(space_dict.values())

        query = """ INSERT OR REPLACE INTO spaces(space_id, space_name, about, network, symbol, number_of_strategies, strategies_list, number_of_admins, admins, number_of_members, member_list, filters_minScore, filters_onlyMembers, plugins)
                VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?) 
                """
        
        cur.execute(query, space_values)

    # commit changes to the database
    conn.commit()

    # close connection
    close_conn(conn)

# %%
# call the insert function

# load spaces from backup csv
df_spaces = pd.read_csv('snapshot_spaces_nov2022.csv',  sep=";")  

# turn data frame into list of dictionaries
spaces_dict_list = df_spaces.to_dict('records')

# insert spaces into table
insert_spaces(spaces_dict_list)
# Out:
# successfully connected to the db
# Connection has been closed

# %% [markdown]
# #### 7.2.2 Insert into proposals table

# %%
# insert all proposals into proposals table

def insert_proposals(proposals_dict_list):
    """
    This function connects to the snapshot_sqlite database and inserts all proposals into the proposals table
    :param proposals_dict_list: list of dicts
    """

    # creat connection to the data base
    conn = create_connection( r"snapshot_sqlite_nov2022.db")
    cur = conn.cursor()

    # loop through dicts in dict list and insert them into the data base
    for proposal_dict in proposals_dict_list:
        proposal_values = list(proposal_dict.values())

        query = """ INSERT OR REPLACE INTO proposals(space_id, space_name, proposal_id, title, body, choices, start, end, snapshot, state, scores, scores_by_strategy, scores_total, scores_updated, author)
                VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?) 
                """
        
        cur.execute(query, proposal_values)

    # commit changes to the database
    conn.commit()

    # close connection
    close_conn(conn)

# %%
proposals_dict_list[2]
# Out:
# {'space_id': 'ufode.eth',
#  'space_name': 'UFO Finance',
#  'id': '0x00b88e72b4d422fbd775d5ba36f8d25431226b5a00113019ddfb2dff12b8f70c',
#  'title': '  Can our project recruit more volunteers to join the promotion?',
#  'body': '',
#  'choices': ['YES', 'NO'],
#  'start': 1642305600,
#  'end': 1642392000,
#  'snapshot': '14014693',
#  'state': 'closed',
#  'scores': [0, 0],
#  'scores_by_strategy': [[0], [0]],
#  'scores_total': 0,
#  'scores_updated': 1642392018,
#  'author': '0xa7c30BC54E3ce11dB9de9D74e5ea7C1a08770163'}

# %%
# call the insert function

# load proposals from backup csv
df_proposals = pd.read_csv('snapshot_proposals_nov2022.csv',  sep=";")  

# turn data frame into list of dictionaries
proposals_dict_list = df_proposals.to_dict('records')

# insert proposals into table
insert_proposals(proposals_dict_list)
# Out:
# successfully connected to the db
# Connection has been closed

# %% [markdown]
# #### 7.2.3 Insert into votes table

# %%
# insert all votes into votes table

def insert_votes(votes_dict_list):
    """
    This function connects to the snapshot_sqlite database and inserts all votes into the votes table
    :param votes_dict_list: list of dicts
    """

    # creat connection to the data base
    conn = create_connection( r"snapshot_sqlite_nov2022.db")
    cur = conn.cursor()

    # loop through dicts in dict list and insert them into the data base
    for vote_dict in votes_dict_list:
        vote_values = list(vote_dict.values())
        
        # ensure data types are correct
        vote_values[0] = str(vote_values[0])
        vote_values[1] = str(vote_values[1])
        vote_values[2] = str(vote_values[2])
        vote_values[3] = str(vote_values[3])
        vote_values[4] = str(vote_values[4])
        vote_values[5] = str(vote_values[5])
        vote_values[6] = str(vote_values[6])
        vote_values[7] = str(vote_values[7])
        vote_values[8] = str(vote_values[8])

        query = """ INSERT OR REPLACE INTO votes(voter_proposal_id, voter, proposal_id, vp, vp_by_strategy, vp_state, created, choice, space_id)
                VALUES(?,?,?,?,?,?,?,?,?) 
                """
        
        cur.execute(query, vote_values)

    # commit changes to the database
    conn.commit()

    # close connection
    close_conn(conn)

# %%
# call the insert function

# load votes from backup csv
df_votes = pd.read_csv('snapshot_votes_nov2022.csv',  sep=";")  

# turn data frame into list of dictionaries
votes_dict_list = df_votes.to_dict('records')

# insert proposals into table
insert_votes(votes_dict_list)
# Out:
# c:\Users\DanielObermeier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# successfully connected to the db
# Connection has been closed

# %% [markdown]
# #### 7.2.4 Insert into follows table

# %%
# insert all following relationships into follows table

def insert_follows(follows_dict_list):
    """
    This function connects to the snapshot_sqlite database and inserts all following relationships into the follows table
    :param follows_dict_list: list of dicts
    """

    # creat connection to the data base
    conn = create_connection( r"snapshot_sqlite.db")
    cur = conn.cursor()

    # loop through dicts in dict list and insert them into the data base
    try:
        for follow_dict in follows_dict_list:
            follow_values = list(follow_dict.values())

            query = """ INSERT OR REPLACE INTO follows(follow_id, follower_id, space_id, created)
                        VALUES(?,?,?,?) 
                        """
                
            cur.execute(query, follow_values)

    except:
        print("could not insert data")

    # commit changes to the database
    conn.commit()

    # close connection
    close_conn(conn)

# %%
# call the insert function

# load follows from backup csv
df_follows = pd.read_csv('snapshot_follows.csv',  sep=";")  

# turn data frame into list of dictionaries
follows_dict_list = df_follows.to_dict('records')

# insert proposals into table
insert_follows(follows_dict_list)
# Out:
# successfully connected to the db

# %% [markdown]
# # 8. Query the tables (check data)

# %%
# load sql extension and connect to the data base with magic commands
#%%capture
# %load_ext sql
# %sql sqlite:///snapshot_sqlite_nov2022.db

# %%
# 
# %sql select * from spaces limit 10
# %sql select * from proposals limit 10
# %sql select * from votes limit 10

# %%
# %sql select * from users limit 10
# Out:
#  * sqlite:///snapshot_sqlite_nov2022.db
# Done.
# []

# %% [markdown]
# # 9. Show descriptives of available DAO data
